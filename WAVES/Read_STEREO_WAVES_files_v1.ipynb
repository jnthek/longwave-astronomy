# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# wfile = np.loadtxt("19950126.R1")
wfile = np.loadtxt("swaves_average_20200101_a_hfr.dat", skiprows=2)
print (wfile.shape)

# flow=1.075
# fhigh=13.825
# freq = np.linspace(flow, fhigh, 256)
# Out:
# (1440, 320)

# %%
plt.imshow(wfile, aspect='auto', vmin=1.0, vmax=2.0)

# %%
plt.figure()
plt.plot(freq, wfile[:,-1])

plt.figure()
plt.plot(freq, np.mean(wfile[:, 0:-2], axis=1))
